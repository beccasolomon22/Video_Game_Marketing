# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Step 1: Load and preprocess the data
data = pd.read_csv('videogames_final.csv')
data
# Out:
#        Unnamed: 0                     Game_Title Platform    Year  \
# 0               0                     Wii Sports      Wii  2006.0
# 1               1              Super Mario Bros.      NES  1985.0
# 2               2                 Mario Kart Wii      Wii  2008.0
# 3               3              Wii Sports Resort      Wii  2009.0
# 4               4       Pokemon Red/Pokemon Blue       GB  1996.0
# ...           ...                            ...      ...     ...
# 21171       34339               Strawberry Nauts      PSV  2016.0
# 21172       34343               Aiyoku no Eustia      PSV  2014.0
# 21173       34346  Samurai Warriors: Sanada Maru      PS3  2016.0
# 21174       34348        Haitaka no Psychedelica      PSV  2016.0
# 21175       34350            Winning Post 8 2016      PSV  2016.0
#
#               Genre        Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0            Sports         Nintendo     41.49     29.02      3.77
# ...

# %%
# data['Success_sales'] = np.where(data['Global_Sales']>= 4, 'Good', 'Bad')

# %%
# Perform any necessary data cleaning and preprocessing here
# Step 2: Feature Engineering
# Extract relevant features and preprocess them if needed
features = data[['NA_Sales', 'EU_Sales']]
target = data['Genre']

# %%
# Example feature preprocessing (you can modify this based on your requirements)
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
# Step 3: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.2, random_state=42)

# %%
# Step 4: Build and train the neural network model
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(4,)))  # Adjust the input shape based on the number of features

# %%
model.add(Dense(64, activation='relu'))

# %%
model.add(Dense(10, activation='softmax'))

# %%
 # Adjust the output size based on the number of genres
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model.fit(X_train, y_train, epochs=10, batch_size=32)
#
# File ~\anaconda3\envs\dev\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filew5vxmora.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ...

# %%
# Step 5: Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
