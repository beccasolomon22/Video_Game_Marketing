# %%
#import dependencies
import pandas as pd

# %%
#import data 
games_global_df = pd.read_csv('data/Games_Global_Sales_Rank.csv')
games_global_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#import data 
video_games_df = pd.read_csv('data/Video_Games_Sales_Users_Rating.csv')
video_games_df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
#merge the first two dataframes. 
top_sales = pd.merge(video_games_df,games_global_df, how = 'left')
top_sales.drop(columns = ['Year'])
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16715  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16716               LMA Manager 2007     X360           2006.0        Sports
# 16717        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16718               Spirits & Spells      GBA           2003.0      Platform
# 16719            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
top_sales = top_sales.fillna('NULL')
top_sales
# Out:
#                                 Name Platform Year_of_Release         Genre  \
# 0                         Wii Sports      Wii          2006.0        Sports
# 1                  Super Mario Bros.      NES          1985.0      Platform
# 2                     Mario Kart Wii      Wii          2008.0        Racing
# 3                  Wii Sports Resort      Wii          2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB          1996.0  Role-Playing
# ...                              ...      ...             ...           ...
# 16715  Samurai Warriors: Sanada Maru      PS3          2016.0        Action
# 16716               LMA Manager 2007     X360          2006.0        Sports
# 16717        Haitaka no Psychedelica      PSV          2016.0     Adventure
# 16718               Spirits & Spells      GBA          2003.0      Platform
# 16719            Winning Post 8 2016      PSV          2016.0    Simulation
#
# ...

# %%
#import data 
game_review_df = pd.read_csv('data/Games_Review_Score.csv')
game_review_df
# Out:
#              Console                                           GameName  \
# 0                 PC                Baldur's Gate 3 Early Access Review
# 1                 NS     Control: Ultimate Edition Cloud Version Review
# 2      XONE, PC, PS4       Doom Eternal: The Ancient Gods Part 1 Review
# 3      XONE, PC, PS4                          Watch Dogs: Legion Review
# 4                 PC                                Ring Of Pain Review
# ...              ...                                                ...
# 14796             PC                                     Doom II Review
# 14797             PC  Dungeon Master II: The Legend of Skullkeep Review
# 14798             PC                                    Endorfun Review
# 14799             PC                              FIFA Soccer 96 Review
# 14800             PC                               Full Throttle Review
#
#              Review  Score
# 0      Early Access      6
# 1              Good      7
# ...

# %%
#import data 
steam_sales_df = pd.read_csv('data/steam_Games.csv')
steam_sales_df = steam_sales_df.drop(columns =['id','positivity_ratio']).fillna('NULL')
steam_sales_df
# Out:
#                                                     name    year  \
# 0                                    The Tiny Bang Story  2011.0
# 1                         World of Guns: Gun Disassembly  2014.0
# 2      Microsoft Flight Simulator 40th Anniversary Ed...  2020.0
# 3                                                Hacknet  2015.0
# 4                                              SpaceChem  2011.0
# ...                                                  ...     ...
# 63538                                   Uncharted Waters  2017.0
# 63539                                     Kid Chameleon™  2010.0
# 63540                                   Fatal Labyrinth™  2010.0
# 63541                              Sangokushi Eiketsuden  2017.0
# 63542           Million Arthur VR: Character Command RPG  2017.0
#
#       metacritic_rating reviewer_rating to_beat_main to_beat_extra  \
# 0                  63.0             8.0          3.6           3.6
# ...

# %%
#regex to separate tags columns
steam_sales_df[['tags1','tags2','tags3','tags4']]  = steam_sales_df['tags'].str.split('|', n=3, expand=True)
steam_sales_df.head(5)
# Out:
#                                                 name    year  \
# 0                                The Tiny Bang Story  2011.0
# 1                     World of Guns: Gun Disassembly  2014.0
# 2  Microsoft Flight Simulator 40th Anniversary Ed...  2020.0
# 3                                            Hacknet  2015.0
# 4                                          SpaceChem  2011.0
#
#   metacritic_rating reviewer_rating to_beat_main to_beat_extra  \
# 0              63.0             8.0          3.6           3.6
# 1              NULL             8.0          2.0          NULL
# 2              91.0             6.0         NULL          NULL
# 3              82.0             8.0         7.06          8.73
# 4              84.0             8.0        43.32         57.79
#
#   to_beat_completionist extra_content_length  \
# 0                  3.77                 0.17
# 1                 28.07                26.07
# 2                  NULL                 NULL
# ...
